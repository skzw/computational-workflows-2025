# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.4.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /Users/leo/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /Users/leo/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /Users/leo/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /Users/leo/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /Users/leo/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /Users/leo/.docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /Users/leo/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/leo/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /Users/leo/.docker/cli-plugins/docker-mcp
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/leo/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /Users/leo/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 3
#   Running: 0
#   Paused: 0
#   Stopped: 3
#  Images: 9
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: x86_64
#  CPUs: 16
#  Total Memory: 7.654GiB
#  Name: docker-desktop
#  ID: 403e8953-81eb-47e4-ac6d-0cb20ba3b716
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/leo/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?

# %% [markdown]
# A container is a standard unit of software that packages up code and all its dependencies so the application runs quickly and reliably from one computing environment to another. A Docker container image is a  package of software that includes everything needed to run an application.

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# Containers are a solution to the problem of how to get software to run reliably when moved from one computing environment to another. This could be from a developer's laptop to a test environment or from a staging environment into production.

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# A docker image is a lightweight, standalone, executable package of software that includes everything needed to run an application: code, runtime, system tools, system libraries and settings.

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly
# !docker login
# Out:
# Authenticating with existing credentials... [Username: skzw]
#
# i Info → To login with a different account, run 'docker logout' followed by 'docker login'
#
#
# Login Succeeded

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# the container ID is 92ae47af51a3
# Out:
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED          STATUS                      PORTS     NAMES
# 92ae47af51a3   hello-world                           "/hello"                 22 seconds ago   Exited (0) 22 seconds ago             jolly_franklin
# 80d8d833cd77   quay.io/biocontainers/python:3.9--1   "/usr/local/env-exec…"   22 hours ago     Exited (255) 2 hours ago              nxf-6d0YItbab874y0T8TebPnAlr
# 70ba5de57850   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago     Exited (137) 23 hours ago             nxf-XBb0768BNUBDQS2SVyU4Pc3K
# e3b9b050d1f6   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago     Exited (137) 23 hours ago             nxf-J27Y8WVESHou1jHtKbbttwlc

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker ps -a
# delete the container
# !docker rm 0d02280d0b49
# check if its deleted
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED          STATUS                      PORTS     NAMES
# 0d02280d0b49   hello-world                           "/hello"                 27 seconds ago   Exited (0) 26 seconds ago             jolly_mclean
# 80d8d833cd77   quay.io/biocontainers/python:3.9--1   "/usr/local/env-exec…"   22 hours ago     Exited (255) 3 hours ago              nxf-6d0YItbab874y0T8TebPnAlr
# 70ba5de57850   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago     Exited (137) 23 hours ago             nxf-XBb0768BNUBDQS2SVyU4Pc3K
# e3b9b050d1f6   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago     Exited (137) 23 hours ago             nxf-J27Y8WVESHou1jHtKbbttwlc
# 0d02280d0b49
# CONTAINER ID   IMAGE                                 COMMAND                  CREATED        STATUS                      PORTS     NAMES
# 80d8d833cd77   quay.io/biocontainers/python:3.9--1   "/usr/local/env-exec…"   22 hours ago   Exited (255) 3 hours ago              nxf-6d0YItbab874y0T8TebPnAlr
# 70ba5de57850   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago   Exited (137) 23 hours ago             nxf-XBb0768BNUBDQS2SVyU4Pc3K
# e3b9b050d1f6   quay.io/biocontainers/wget:1.20.1     "/bin/bash -c 'eval …"   24 hours ago   Exited (137) 23 hours ago             nxf-J27Y8WVESHou1jHtKbbttwlc

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. Go to fastqc website and dowload the zip file for command line use
# 2. add execution permissions to the fastqc file
# 3. make it availabl everywhere
# ...

# %%
# !fastqc --help
# Out:
#             FastQC - A high throughput sequence QC analysis tool
#
# SYNOPSIS
#
# 	fastqc seqfile1 seqfile2 .. seqfileN
#
#     fastqc [-o output dir] [--(no)extract] [-f fastq|bam|sam]
#            [-c contaminant file] seqfile1 .. seqfileN
#
# DESCRIPTION
#
#     FastQC reads a set of sequence files and produces from each one a quality
#     control report consisting of a number of different modules, each one of
#     which will help to identify a different potential type of problem in your
#     data.
#
#     If no files to process are specified on the command line then the program
#     will start as an interactive graphical application.  If files are provided
#     on the command line then the program will run with no user interaction
#     required.  In this mode it is suitable for inclusion into a standardised
#     analysis pipeline.
#
#     The options for the program as as follows:
#
#     -h --help       Print this help file and exit
#
#     -v --version    Print the version of the program and exit
#
#     -o --outdir     Create all output files in the specified output directory.
#                     Please note that this directory must exist as the program
#                     will not create it.  If this option is not set then the
#                     output file for each sequence file is created in the same
#                     directory as the sequence file which was processed.
#
#     --casava        Files come from raw casava output. Files in the same sample
#                     group (differing only by the group number) will be analysed
#                     as a set rather than individually. Sequences with the filter
#                     flag set in the header will be excluded from the analysis.
#                     Files must have the same names given to them by casava
#                     (including being gzipped and ending with .gz) otherwise they
#                     won't be grouped together correctly.
#
#     --nano          Files come from nanopore sequences and are in fast5 format. In
#                     this mode you can pass in directories to process and the program
#                     will take in all fast5 files within those directories and produce
#                     a single output file from the sequences found in all files.
#
#     --nofilter      If running with --casava then don't remove read flagged by
#                     casava as poor quality when performing the QC analysis.
#
#     --extract       If set then the zipped output file will be uncompressed in
#                     the same directory after it has been created. If --delete is
#                     also specified then the zip file will be removed after the
#                     contents are unzipped.
#
#     -j --java       Provides the full path to the java binary you want to use to
#                     launch fastqc. If not supplied then java is assumed to be in
#                     your path.
#
#     --noextract     Do not uncompress the output file after creating it.  You
#                     should set this option if you do not wish to uncompress
#                     the output when running in non-interactive mode.
#
#     --nogroup       Disable grouping of bases for reads >50bp. All reports will
#                     show data for every base in the read.  WARNING: Using this
#                     option will cause fastqc to crash and burn if you use it on
#                     really long reads, and your plots may end up a ridiculous size.
#                     You have been warned!
#
#     --min_length    Sets an artificial lower limit on the length of the sequence
#                     to be shown in the report.  As long as you set this to a value
#                     greater or equal to your longest read length then this will be
#                     the sequence length used to create your read groups.  This can
#                     be useful for making directly comaparable statistics from
#                     datasets with somewhat variable read lengths.
#
#     --dup_length    Sets a length to which the sequences will be truncated when
#                     defining them to be duplicates, affecting the duplication and
#                     overrepresented sequences plot.  This can be useful if you have
#                     long reads with higher levels of miscalls, or contamination with
#                     adapter dimers containing UMI sequences.
#
#
#     -f --format     Bypasses the normal sequence file format detection and
#                     forces the program to use the specified format.  Valid
#                     formats are bam,sam,bam_mapped,sam_mapped and fastq
#
#
#     --memory        Sets the base amount of memory, in Megabytes, used to process
#                     each file.  Defaults to 512MB.  You may need to increase this if
#                     you have a file with very long sequences in it.
#
#     --svg           Save the graphs in the report in SVG format.
#
#     -t --threads    Specifies the number of files which can be processed
#                     simultaneously.  Each thread will be allocated 250MB of
#                     memory so you shouldn't run more threads than your
#                     available memory will cope with, and not more than
#                     6 threads on a 32 bit machine
#
#     -c              Specifies a non-default file which contains the list of
#     --contaminants  contaminants to screen overrepresented sequences against.
#                     The file must contain sets of named contaminants in the
#                     form name[tab]sequence.  Lines prefixed with a hash will
#                     be ignored.
#
#     -a              Specifies a non-default file which contains the list of
#     --adapters      adapter sequences which will be explicity searched against
#                     the library. The file must contain sets of named adapters
#                     in the form name[tab]sequence.  Lines prefixed with a hash
#                     will be ignored.
#
#     -l              Specifies a non-default file which contains a set of criteria
#     --limits        which will be used to determine the warn/error limits for the
#                     various modules.  This file can also be used to selectively
#                     remove some modules from the output all together.  The format
#                     needs to mirror the default limits.txt file found in the
#                     Configuration folder.
#
#    -k --kmers       Specifies the length of Kmer to look for in the Kmer content
#                     module. Specified Kmer length must be between 2 and 10. Default
#                     length is 7 if not specified.
#
#    -q --quiet       Suppress all progress messages on stdout and only report errors.
#
#    -d --dir         Selects a directory to be used for temporary files written when
#                     generating report images. Defaults to system temp directory if
#                     not specified.
#
# BUGS
#
#     Any bugs in fastqc should be reported either to simon.andrews@babraham.ac.uk
#     or in www.bioinformatics.babraham.ac.uk/bugzilla/

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull quay.io/biocontainers/fastqc:0.11.9--0
# Out:
# 0.11.9--0: Pulling from biocontainers/fastqc
#
# Digest: sha256:70de12400206b9c1784c8dfd019cfe4e42eed9a42eabf6c61eb68342843bdaab[1A
# Status: Downloaded newer image for quay.io/biocontainers/fastqc:0.11.9--0
# quay.io/biocontainers/fastqc:0.11.9--0

# %%
# !docker run --rm -v $(pwd):/data quay.io/biocontainers/fastqc:0.11.9--0 fastqc /data/SRX19144486_SRR23195516_1.fastq.gz -o /data/fastqc_results
# Out:
# Started analysis of SRX19144486_SRR23195516_1.fastq.gz
# Approx 5% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 10% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 15% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 20% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 25% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 30% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 35% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 40% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 45% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 50% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 55% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 60% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 65% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 70% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 75% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 80% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 85% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 90% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 95% complete for SRX19144486_SRR23195516_1.fastq.gz
# Analysis complete for SRX19144486_SRR23195516_1.fastq.gz

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?

# %% [markdown]
# ### What would you say, which approach is more reproducible?
# The docker approach is more reproducible because the container holds all dependencies and versions of the software.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?
# They are probably not identical.

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %%
# build the docker image
# !docker build -t mycowsay -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
# [+] Building 0.9s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.1s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
# [+] Building 1.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
# [+] Building 1.4s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
# [+] Building 1.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
# [+] Building 1.7s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
# [+] Building 1.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.8s
# [+] Building 2.0s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.9s
# [+] Building 2.1s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.1s
# [+] Building 2.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.2s
# [+] Building 2.4s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.4s
# [+] Building 2.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.5s
# [+] Building 2.7s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.7s
# [+] Building 2.9s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.8s
# [+] Building 3.0s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.0s
# [+] Building 3.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.1s
# [+] Building 3.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.3s
# [+] Building 3.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.4s
# [+] Building 3.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.6s
# [+] Building 3.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.7s
# [+] Building 3.8s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    3.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.1s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.3s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.5s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 4.8s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 5.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# [+] Building 5.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.2s
# [+] Building 5.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.3s
# [+] Building 5.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.4s
# [+] Building 5.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.6s
# [+] Building 5.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.8s
# [+] Building 5.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.9s
# [+] Building 5.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.9s
# [+] Building 6.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  1.0s
# [+] Building 6.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  1.2s
# [+] Building 6.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  1.2s
# [+] Building 6.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  1.4s
# [+] Building 6.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  1.5s
# [+] Building 6.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  1.6s
# [+] Building 6.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  1.8s
# [+] Building 6.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  1.9s
# [+] Building 7.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  2.1s
# [+] Building 7.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 3.15MB / 30.26MB  2.1s
# [+] Building 7.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  2.3s
# [+] Building 7.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  2.4s
# [+] Building 7.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  2.6s
# [+] Building 7.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.6s
# [+] Building 7.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.7s
# [+] Building 7.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.9s
# [+] Building 7.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  2.9s
# [+] Building 7.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  3.0s
# [+] Building 7.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  3.0s
# [+] Building 8.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  3.2s
# [+] Building 8.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  3.3s
# [+] Building 8.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.4s
# [+] Building 8.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.6s
# [+] Building 8.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.6s
# [+] Building 8.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.8s
# [+] Building 8.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.8s
# [+] Building 8.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  3.9s
# [+] Building 9.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  4.1s
# [+] Building 9.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  4.1s
# [+] Building 9.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  4.2s
# [+] Building 9.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 10.49MB / 30.26MB  4.4s
# [+] Building 9.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 10.49MB / 30.26MB  4.5s
# [+] Building 9.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 10.49MB / 30.26MB  4.7s
# [+] Building 9.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  4.7s
# [+] Building 9.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  4.8s
# [+] Building 9.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  5.0s
# [+] Building 10.0s (4/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  5.1s
# [+] Building 10.2s (4/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  5.3s
# ...
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 41.5s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
# [+] Building 41.6s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 41.8s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.2s
#  => => exporting layers                                                    2.2s
# [+] Building 41.9s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    2.3s
# [+] Building 41.9s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    2.4s
# [+] Building 42.2s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.5s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.1s
# [+] Building 42.3s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.7s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.2s
# [+] Building 42.5s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     2.8s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.4s
# [+] Building 42.6s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.5s
# [+] Building 42.7s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     3.1s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.7s
# [+] Building 42.9s (7/7) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 943B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    4.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  10.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  9.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&     24.4s
#  => exporting to image                                                     3.2s
#  => => exporting layers                                                    2.4s
#  => => exporting manifest sha256:782173b7e6b0424f74470f63f19e9f897bc4b08c  0.0s
#  => => exporting config sha256:9bbd9ded993b0180f0b4ba149a9817c3bc5b58873f  0.0s
#  => => exporting attestation manifest sha256:62ef28df46864ea74d7bdb63b626  0.0s
#  => => exporting manifest list sha256:51872f9f9aad6661d04ab7ad7219a01edb8  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.7s
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                                                 TAG                     IMAGE ID       CREATED          SIZE
# mycowsay                                                   latest                  51872f9f9aad   15 seconds ago   197MB
# hello-world                                                latest                  54e66cc1dd1f   7 weeks ago      20.3kB
# quay.io/biocontainers/samtools                             1.21--h50ea8bc_0        783c6646029a   12 months ago    108MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0    e0de72408557   17 months ago    1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0       099d0e113ec8   18 months ago    1.82GB
# quay.io/biocontainers/pandas                               1.5.2                   cbb54fcf8730   2 years ago      493MB
# quay.io/biocontainers/r-base                               4.2.1                   6721ee8bfba2   2 years ago      1.17GB
# quay.io/biocontainers/p7zip                                16.02                   731aaeef376a   3 years ago      47.7MB
# quay.io/biocontainers/python                               3.9--1                  d97d2b329b4e   4 years ago      275MB
# biocontainers/fastqc                                       v0.11.9_cv7             8ff2a75c6864   4 years ago      1.23GB
# quay.io/biocontainers/wget                                 1.20.1                  7e5ba9e87a25   6 years ago      123MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3   c06884d353ef   55 years ago     452MB
# quay.io/biocontainers/fastqc                               0.11.9--0               70de12400206   55 years ago     265MB

# %%
# run the docker file 
# !docker run mycowsay
# Out:
#  __
# <  >
#  --
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image 
! docker build -t mysalmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
# [+] Building 0.3s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.1s
# [+] Building 1.4s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.3s
# [+] Building 1.6s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.4s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.7s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.8s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
# [+] Building 1.9s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.1s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.2s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.4s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.5s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.7s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.8s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.0s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.1s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.3s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.4s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.6s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.7s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.9s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.0s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.2s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.3s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.5s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.6s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.8s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.9s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.1s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.9s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 5.2s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.1s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 5.4s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.2s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 5.4s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.2s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.5s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.7s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.5s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.8s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.0s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.8s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.0s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.8s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 5s (1860 kB/s)
#  => => # Reading package lists...
# [+] Building 6.1s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.0s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 5s (1860 kB/s)
#  => => # Reading package lists...
# [+] Building 6.3s (5/7)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# ...
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     8.2s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      0.4s
# [+] Building 32.9s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     8.4s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      0.6s
# [+] Building 33.1s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     8.5s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      0.7s
# [+] Building 33.2s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     8.7s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      0.9s
# [+] Building 33.4s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     8.8s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.0s
# [+] Building 33.5s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.0s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.2s
# [+] Building 33.7s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.1s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.3s
# [+] Building 33.8s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.3s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.5s
# [+] Building 34.0s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.4s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.6s
# [+] Building 34.0s (7/8)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.5s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.7s
# [+] Building 34.2s (8/8) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 542B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  12.1s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  11.4s
#  => exporting to image                                                     9.5s
#  => => exporting layers                                                    7.7s
#  => => exporting manifest sha256:b6ce0d54f7c07ad6928c70a65134906583cc3b67  0.0s
#  => => exporting config sha256:6f8070e471a8a2c729025688ba54d5129e19e42eb8  0.0s
#  => => exporting attestation manifest sha256:3ed600d70ea3416a158d886ef3e8  0.0s
#  => => exporting manifest list sha256:5948c446ed3ee973ad734827bc55e8b7d23  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#  => => unpacking to docker.io/library/mysalmon:latest                      1.7s

# %%
# build the image
# !docker images
# Out:
# REPOSITORY                                                 TAG                     IMAGE ID       CREATED          SIZE
# mysalmon                                                   latest                  5948c446ed3e   35 seconds ago   407MB
# mycowsay                                                   latest                  51872f9f9aad   9 minutes ago    197MB
# hello-world                                                latest                  54e66cc1dd1f   7 weeks ago      20.3kB
# quay.io/biocontainers/samtools                             1.21--h50ea8bc_0        783c6646029a   12 months ago    108MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0    e0de72408557   17 months ago    1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0       099d0e113ec8   18 months ago    1.82GB
# quay.io/biocontainers/pandas                               1.5.2                   cbb54fcf8730   2 years ago      493MB
# quay.io/biocontainers/r-base                               4.2.1                   6721ee8bfba2   2 years ago      1.17GB
# quay.io/biocontainers/p7zip                                16.02                   731aaeef376a   3 years ago      47.7MB
# quay.io/biocontainers/python                               3.9--1                  d97d2b329b4e   4 years ago      275MB
# biocontainers/fastqc                                       v0.11.9_cv7             8ff2a75c6864   4 years ago      1.23GB
# quay.io/biocontainers/wget                                 1.20.1                  7e5ba9e87a25   6 years ago      123MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3   c06884d353ef   55 years ago     452MB
# quay.io/biocontainers/fastqc                               0.11.9--0               70de12400206   55 years ago     265MB

# %%
# run the docker image to give out the version of salmon
# !docker run mysalmon salmon
# Out:
# salmon v1.5.2
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index      : create a salmon index
#      quant      : quantify a sample
#      alevin     : single cell analysis
#      swim       : perform super-secret operation
#      quantmerge : merge multiple quantifications into a single file

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
# https://hub.docker.com/r/combinelab/salmon
#
# What is https://biocontainers.pro/ ?
# A community-driven project to create and manage bioinformatics software containers. (from github)

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
# Docker images can be created with other tools for example with conda and mamba.
#
# What is https://seqera.io/containers/ ?
# A registry for container images optimized for bioinformatics. (from their website)
